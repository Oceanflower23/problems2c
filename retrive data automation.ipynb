# %%
# !pip install selenium
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\User\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# !apt-get update
# !apt-get install -yq chromium-chromedriver xvfb
# !pip install pyvirtualdisplay
# !pip install pyppeteer
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\User\anaconda3\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\User\anaconda3\python.exe -m pip install --upgrade pip' command.
# ...

# %%
# !pip install webdriver_manager
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\User\anaconda3\python.exe -m pip install --upgrade pip' command.
# ...

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Path to your ChromeDriver executable
driver_path = 'C:/Users/User/Downloads/chromedriver_win32/chromedriver.exe'

# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")

# Start the WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# Open the webpage
driver.get('https://embodiedcognitionlab.shinyapps.io/sensorimotor_norms/')

# Find the textarea element and paste the data
textarea = driver.find_element(By.ID, 'text')
with open('C:/Users/User/Desktop/automate/lemmatized_dementia_text.csv', 'r') as file:
    first_entry = file.readline().strip()
    textarea.send_keys(first_entry)

# Wait for the website to process the data (you can adjust the sleep duration as needed)
time.sleep(5)

# Retrieve the download URL
download_url = driver.find_element(By.ID, 'downloadData').get_attribute('href')

# Download the file
response = requests.get(download_url)
with open('C:/Users/User/Desktop/automate/downloaded_file.csv', 'wb') as file:
    file.write(response.content)

# Close the WebDriver
driver.quit()
# Out:
# Exception ignored in: <function Service.__del__ at 0x000001FEC43F6040>
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\common\service.py", line 184, in __del__
#     self.stop()
#   File "C:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\common\service.py", line 145, in stop
#     self.send_remote_shutdown_command()
#   File "C:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\common\service.py", line 124, in send_remote_shutdown_command
#     request.urlopen(f"{self.service_url}/shutdown")
#   File "C:\Users\User\anaconda3\lib\urllib\request.py", line 214, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\User\anaconda3\lib\urllib\request.py", line 517, in open
#     response = self._open(req, data)
#   File "C:\Users\User\anaconda3\lib\urllib\request.py", line 534, in _open
#     result = self._call_chain(self.handle_open, protocol, protocol +
# ...

# %%
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Path to your ChromeDriver executable
driver_path = 'C:/Users/User/Downloads/chromedriver_win32/chromedriver.exe'

# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")

# Start the WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# Open the webpage
driver.get('https://embodiedcognitionlab.shinyapps.io/sensorimotor_norms/')

# Read the entries from the file
with open('C:/Users/User/Desktop/automate/lemmatized_dementia_text.csv', 'r') as file:
    entries = file.readlines()

# Loop through each entry and process it
for index, entry in enumerate(entries):
    # Find the textarea element and paste the data
    textarea = driver.find_element(By.ID, 'text')
    textarea.clear()
    textarea.send_keys(entry.strip())

    # Wait for the website to process the data (you can adjust the sleep duration as needed)
    time.sleep(5)

    # Retrieve the download URL
    download_url = driver.find_element(By.ID, 'downloadData').get_attribute('href')

    # Download the file
    response = requests.get(download_url)
    filename = f'C:/Users/User/Desktop/automate/downloaded_file_{index+1}.csv'
    with open(filename, 'wb') as file:
        file.write(response.content)
    print(f'Saved file: {filename}')

# Close the WebDriver
driver.quit()
# Out:
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_1.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_2.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_3.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_4.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_5.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_6.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_7.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_8.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_9.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_10.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_11.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_12.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_13.csv
# Saved file: C:/Users/User/Desktop/automate/downloaded_file_14.csv
# ...

# %%
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Path to your ChromeDriver executable
driver_path = 'C:/Users/User/Downloads/chromedriver_win32/chromedriver.exe'

# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")

# Start the WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# Open the webpage
driver.get('https://embodiedcognitionlab.shinyapps.io/sensorimotor_norms/')

# Read the entries from the file
with open('C:/Users/User/Desktop/REDDIT DATA/dementia/lemmatized_control_text.csv', 'r') as file:
    entries = file.readlines()

# Loop through each entry and process it
for index, entry in enumerate(entries):
    # Find the textarea element and paste the data
    textarea = driver.find_element(By.ID, 'text')
    textarea.clear()
    textarea.send_keys(entry.strip())

    # Wait for the website to process the data (you can adjust the sleep duration as needed)
    time.sleep(5)

    # Retrieve the download URL
    download_url = driver.find_element(By.ID, 'downloadData').get_attribute('href')

    # Download the file
    response = requests.get(download_url)
    filename = f'C:/Users/User/Desktop/automate control/downloaded_file_{index+1}.csv'
    with open(filename, 'wb') as file:
        file.write(response.content)
    print(f'Saved file: {filename}')

# Close the WebDriver
driver.quit()
# Out:
# [WDM] - Downloading: 100%|██████████| 6.81M/6.81M [00:00<00:00, 29.9MB/s]
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_1.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_2.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_3.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_4.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_5.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_6.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_7.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_8.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_9.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_10.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_11.csv
# Saved file: C:/Users/User/Desktop/automate control/downloaded_file_12.csv
# ...
